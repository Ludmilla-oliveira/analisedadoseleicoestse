# %%
#!pip install Matplotlib

# %%
#IMPORTAÇÃO DAS BIBLIOTECAS
import pandas as pd
import numpy as np
import zipfile
import requests
from io import BytesIO
import os
import glob
import seaborn as sns
sns.set_theme(style="whitegrid", palette="muted")
import time

# %%
#Importação da função Counter e da biblioteca matplotlib.pyplot
from collections import Counter
import matplotlib.pyplot as plt

# %% [markdown]
# funçao para descompactar automaticamente os arquivos

# %%
#Definindo a pasta de trabalho
dirCandidatoAnalise = "./candidatopt1420"
os.makedirs(dirCandidatoAnalise, exist_ok=True)

# %%
def descompactar(nome_arquivo_compactado, diretorio):
    #Lê o arquivo compactado e extrai o conteúdo
    print(nome_arquivo_compactado)
    filebytes = BytesIO(
        requests.get(nome_arquivo_compactado).content
    )
    myzip = zipfile.ZipFile(filebytes)
    myzip.extractall(diretorio)
    return "Concluído"

# %% [markdown]
# Criação da estrutura de repetição para executar a quantidade de parâmetros predefinida

# %%
ca = 2014
while ca < 2022:
    urlCandidatoAnalise = "https://cdn.tse.jus.br/estatistica/sead/odsele/consulta_cand/consulta_cand_" + str(ca)+ ".zip"
    descompactar(urlCandidatoAnalise,dirCandidatoAnalise)
    ca+=2
# Out:
# https://cdn.tse.jus.br/estatistica/sead/odsele/consulta_cand/consulta_cand_2014.zip
# https://cdn.tse.jus.br/estatistica/sead/odsele/consulta_cand/consulta_cand_2016.zip
# https://cdn.tse.jus.br/estatistica/sead/odsele/consulta_cand/consulta_cand_2018.zip
# https://cdn.tse.jus.br/estatistica/sead/odsele/consulta_cand/consulta_cand_2020.zip

# %%
print('Arquivos com extensão csv Candidato:')
concatenar = []
with os.scandir(dirCandidatoAnalise) as arqs:
    for arq in arqs:
        if arq.is_file() and  arq.name.endswith('.csv'):
             print(arq.name)
    path = dirCandidatoAnalise
    # csv files in the path
    files = glob.glob(path + "/*.csv")
    # defining an empty list to store 
    # content
    data_frame = pd.DataFrame()
    content = []
    # checking all the csv files in the 
    # specified path
    for filename in files:
        df = pd.read_csv(filename, encoding = "Latin 1", sep= ";", decimal = ',', 
            error_bad_lines=False,dtype={"SQ_CANDIDATO": int, "ANO_ELEICAO": int,"SG_UF" : "string", "NR_TURNO": int,"HH_GERACAO" : object ,"CD_TIPO_ELEICAO" : int,"NM_TIPO_ELEICAO" : "string","CD_ELEICAO" : "string","DS_ELEICAO" : "string","DT_ELEICAO" : "string","TP_ABRANGENCIA" : "string","SG_UE" : "string","NM_UE" : "string","CD_CARGO" : int,"DS_CARGO" : "string","NR_CANDIDATO" : int,"NM_CANDIDATO" : "string","NM_URNA_CANDIDATO" : "string","NM_SOCIAL_CANDIDATO" : "string","NR_CPF_CANDIDATO" : "string","NM_EMAIL" : "string","CD_SITUACAO_CANDIDATURA" : "string","DS_SITUACAO_CANDIDATURA" : "string","CD_DETALHE_SITUACAO_CAND" : "string","DS_DETALHE_SITUACAO_CAND" : "string","TP_AGREMIACAO" : "string","NR_PARTIDO" : int,"SG_PARTIDO" : "string","NM_PARTIDO" : "string","SQ_COLIGACAO" : "string","NM_COLIGACAO" : "string","DS_COMPOSICAO_COLIGACAO" : "string","CD_NACIONALIDADE" : int,"DS_NACIONALIDADE" : "string","SG_UF_NASCIMENTO" : "string","CD_MUNICIPIO_NASCIMENTO" : "string","NM_MUNICIPIO_NASCIMENTO" : "string","DT_NASCIMENTO" : "string","NR_IDADE_DATA_POSSE" : float ,"NR_TITULO_ELEITORAL_CANDIDATO" : "string","CD_GENERO" : int,"DS_GENERO" : "string","CD_GRAU_INSTRUCAO" : int,"DS_GRAU_INSTRUCAO" : "string","CD_ESTADO_CIVIL" : int,"DS_ESTADO_CIVIL" : "string","CD_OCUPACAO" : "string", "DS_OCUPACAO" : "string","VR_DESPESA_MAX_CAMPANHA" : "string","CD_SIT_TOT_TURNO" : "string","DS_SIT_TOT_TURNO" : "string","ST_REELEICAO" : "string","ST_DECLARAR_BENS" : "string","NR_PROTOCOLO_CANDIDATURA" : "string","NR_PROCESSO" : "string" ,"CD_SITUACAO_CANDIDATO_PLEITO" : "string","DS_SITUACAO_CANDIDATO_PLEITO" : "string","CD_SITUACAO_CANDIDATO_URNA" : "string", "DS_SITUACAO_CANDIDATO_URNA" : "string","ST_CANDIDATO_INSERIDO_URNA" : "string"})
        df.drop_duplicates()
        content.append(df)
    # converting content to data frame
    data_frame = pd.concat(content).drop_duplicates()
# Out:
# Arquivos com extensão csv Candidato:
# consulta_cand_2014_AC.csv
# consulta_cand_2014_AL.csv
# consulta_cand_2014_AM.csv
# consulta_cand_2014_AP.csv
# consulta_cand_2014_BA.csv
# consulta_cand_2014_BR.csv
# consulta_cand_2014_BRASIL.csv
# consulta_cand_2014_CE.csv
# consulta_cand_2014_DF.csv
# consulta_cand_2014_ES.csv
# consulta_cand_2014_GO.csv
# consulta_cand_2014_MA.csv
# consulta_cand_2014_MG.csv
# consulta_cand_2014_MS.csv
# consulta_cand_2014_MT.csv
# consulta_cand_2014_PA.csv
# consulta_cand_2014_PB.csv
# consulta_cand_2014_PE.csv
# consulta_cand_2014_PI.csv
# consulta_cand_2014_PR.csv
# consulta_cand_2014_RJ.csv
# consulta_cand_2014_RN.csv
# consulta_cand_2014_RO.csv
# consulta_cand_2014_RR.csv
# consulta_cand_2014_RS.csv
# consulta_cand_2014_SC.csv
# consulta_cand_2014_SE.csv
# consulta_cand_2014_SP.csv
# consulta_cand_2014_TO.csv
# consulta_cand_2016_AC.csv
# consulta_cand_2016_AL.csv
# consulta_cand_2016_AM.csv
# consulta_cand_2016_AP.csv
# consulta_cand_2016_BA.csv
# ...

# %%
display(data_frame.head())
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 1  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 2  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 3  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 4  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO CD_ELEICAO            DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  ...  \
# 0         1        143  Eleições Gerais 2014  05/10/2014        FEDERAL  ...
# 1         1        143  Eleições Gerais 2014  05/10/2014        FEDERAL  ...
# 2         1        143  Eleições Gerais 2014  05/10/2014        FEDERAL  ...
# 3         1        143  Eleições Gerais 2014  05/10/2014        FEDERAL  ...
# 4         1        143  Eleições Gerais 2014  05/10/2014        FEDERAL  ...
#
# ...

# %%
display(data_frame.tail())
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 558014  10/03/2022   12:20:17         2020                2
# 558015  10/03/2022   12:20:17         2020                2
# 558016  10/03/2022   12:20:17         2020                2
# 558017  10/03/2022   12:20:17         2020                2
# 558019  10/03/2022   12:20:17         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO CD_ELEICAO                DS_ELEICAO  \
# 558014  ELEIÇÃO ORDINÁRIA         1        426  Eleições Municipais 2020
# 558015  ELEIÇÃO ORDINÁRIA         1        426  Eleições Municipais 2020
# 558016  ELEIÇÃO ORDINÁRIA         1        426  Eleições Municipais 2020
# 558017  ELEIÇÃO ORDINÁRIA         1        426  Eleições Municipais 2020
# 558019  ELEIÇÃO ORDINÁRIA         1        426  Eleições Municipais 2020
#
#         DT_ELEICAO TP_ABRANGENCIA  ... DS_SIT_TOT_TURNO ST_REELEICAO  \
# 558014  15/11/2020      MUNICIPAL  ...         SUPLENTE            N
# ...

# %%
data_frame.describe()
# Out:
#         ANO_ELEICAO  CD_TIPO_ELEICAO      NR_TURNO      CD_CARGO  \
# count  1.111811e+06     1.111811e+06  1.111811e+06  1.111811e+06
# mean   2.018013e+03     1.998522e+00  1.000525e+00  1.258667e+01
# std    2.044115e+00     3.841337e-02  2.291274e-02  1.411902e+00
# min    2.014000e+03     1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.016000e+03     2.000000e+00  1.000000e+00  1.300000e+01
# 50%    2.020000e+03     2.000000e+00  1.000000e+00  1.300000e+01
# 75%    2.020000e+03     2.000000e+00  1.000000e+00  1.300000e+01
# max    2.020000e+03     2.000000e+00  2.000000e+00  1.300000e+01
#
#        SQ_CANDIDATO  NR_CANDIDATO    NR_PARTIDO  CD_NACIONALIDADE  \
# count  1.111811e+06  1.111811e+06  1.111811e+06      1.111811e+06
# mean   3.634049e+07  2.887349e+04  3.108952e+01      1.003915e+00
# std    1.143453e+09  2.132509e+04  2.034028e+01      8.067383e-02
# min   -1.993005e+09  1.000000e+01  1.000000e+01     -4.000000e+00
# ...

# %%
data_frame.shape
# Out:
# (1111811, 63)

# %%
data_frame['TP_ABRANGENCIA'].unique()
# Out:
# <StringArray>
# ['FEDERAL', 'ESTADUAL', 'MUNICIPAL']
# Length: 3, dtype: string

# %%
res = sns.scatterplot(x=data_frame['ANO_ELEICAO'],y=data_frame['DS_CARGO'])
fig = plt.figure(figsize=(16,8))
plt.show()

# %% [markdown]
# Conforme gráfico acima, pode-se identificar a necessidade de um desmembramento para melhor compreensão das eleições e os cargos eletivos à que se referem.

# %%
data_frame['DS_OCUPACAO'].unique()
# Out:
# <StringArray>
# [                                         'OUTROS',
#                       'ELETRICISTA E ASSEMELHADOS',
#                                      'COMERCIANTE',
#                                       'EMPRESÁRIO',
#                        'SERVIDOR PÚBLICO ESTADUAL',
#                       'SERVIDOR PÚBLICO MUNICIPAL',
#                                         'VEREADOR',
#                                         'DEPUTADO',
#                             'JORNALISTA E REDATOR',
#                         'SERVIDOR PÚBLICO FEDERAL',
#  ...
#                                        'CARVOEIRO',
#              'MESTRE E CONTRAMESTRE DE EMBARCAÇÃO',
#                                           'FÍSICO',
#                                       'MAGISTRADO',
#                     'CONTROLADOR DE TRÁFEGO AÉREO',
#                                       'ARQUEÓLOGO',
#                                     'DEMONSTRADOR',
#                                       'PARAMÉDICO',
# ...

# %%
data_frame['DS_GENERO'].unique()
# Out:
# <StringArray>
# ['MASCULINO', 'FEMININO', 'NÃO DIVULGÁVEL']
# Length: 3, dtype: string

# %%
data_frame['ANO_ELEICAO'].unique()
# Out:
# array([2014, 2016, 2018, 2020])

# %%
data_frame
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0       08/04/2021   11:38:25         2014                2
# 1       08/04/2021   11:38:25         2014                2
# 2       08/04/2021   11:38:25         2014                2
# 3       08/04/2021   11:38:25         2014                2
# 4       08/04/2021   11:38:25         2014                2
# ...            ...        ...          ...              ...
# 558014  10/03/2022   12:20:17         2020                2
# 558015  10/03/2022   12:20:17         2020                2
# 558016  10/03/2022   12:20:17         2020                2
# 558017  10/03/2022   12:20:17         2020                2
# 558019  10/03/2022   12:20:17         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO CD_ELEICAO                DS_ELEICAO  \
# 0       ELEIÇÃO ORDINÁRIA         1        143      Eleições Gerais 2014
# 1       ELEIÇÃO ORDINÁRIA         1        143      Eleições Gerais 2014
# ...

# %%
data_frame_2014 = data_frame[data_frame['ANO_ELEICAO'] == 2014]

# %%
data_frame_2014
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 1      08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 2      08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 3      08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 4      08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 26266  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 26267  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 26268  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 26269  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 26270  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
#
# ...

# %%
data_frame['DS_SIT_TOT_TURNO'].unique()
# Out:
# <StringArray>
# [        'SUPLENTE',    'ELEITO POR QP',       'NÃO ELEITO',
#  'ELEITO POR MÉDIA',           '#NULO#',           'ELEITO',
#          '2º TURNO']
# Length: 7, dtype: string

# %%
#df_nao_eleito_maior_10_mil = df_10_mil.query("VR_BEM_CANDIDATO > 10000000 & DS_SIT_TOT_TURNO == 'NÃO ELEITO'")
#codigo exemplo com filtro de um parametro

# %%
data_frame_pt_2014 = data_frame_2014.query("SG_PARTIDO == 'PT' & DS_SIT_TOT_TURNO == 'ELEITO'")

# %%
# data_frame_pt_2014 = data_frame_2014[data_frame_2014['SG_PARTIDO'] == 'PT']
##codigo exemplo com filtro de um parametro

# %%
data_frame_pt_2014
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 412    08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 539    08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 271    08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 902    08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 4369   08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 7349   08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 7708   08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 13297  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 14270  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 14498  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# 16311  08/04/2021   11:38:25         2014                2  ELEIÇÃO ORDINÁRIA
# ...

# %%
data_frame_pt_2014['SG_PARTIDO'].unique()
# Out:
# <StringArray>
# ['PT']
# Length: 1, dtype: string

# %%
data_frame_pt_2014['DS_OCUPACAO'].unique()
# Out:
# <StringArray>
# [                              'OUTROS',
#                            'GOVERNADOR',
#                              'DEPUTADO',
#       'PROFESSOR DE ENSINO FUNDAMENTAL',
#  'APOSENTADO (EXCETO SERVIDOR PÚBLICO)',
#                            'ECONOMISTA',
#                            'EMPRESÁRIO',
#                              'ADVOGADO',
#                         'ADMINISTRADOR',
#                               'SENADOR']
# Length: 10, dtype: string

# %%
ocupacao_candidatos = Counter(data_frame['DS_OCUPACAO'])
ocupacao_candidatos
#Ocupacao dos candidatos de 2014 a 2020
# Out:
# Counter({'OUTROS': 220272,
#          'ELETRICISTA E ASSEMELHADOS': 5171,
#          'COMERCIANTE': 65032,
#          'EMPRESÁRIO': 65017,
#          'SERVIDOR PÚBLICO ESTADUAL': 13306,
#          'SERVIDOR PÚBLICO MUNICIPAL': 68654,
#          'VEREADOR': 51365,
#          'DEPUTADO': 2648,
#          'JORNALISTA E REDATOR': 3626,
#          'SERVIDOR PÚBLICO FEDERAL': 4167,
#          'GERENTE': 4759,
#          'LOCUTOR E COMENTARISTA DE RÁDIO E TELEVISÃO E RADIALISTA': 3452,
#          'ADVOGADO': 22801,
#          'MÉDICO': 6611,
#          'POLICIAL MILITAR': 8009,
#          'CONTADOR': 4692,
#          'ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS': 18686,
#          'PROFESSOR DE ENSINO MÉDIO': 19642,
#          'BOMBEIRO MILITAR': 867,
#          'TRABALHADOR RURAL': 16650,
#          'ADMINISTRADOR': 15673,
#          'DONA DE CASA': 47859,
#          'PROFESSOR DE ENSINO FUNDAMENTAL': 25616,
#          'ODONTÓLOGO': 2783,
# ...

# %%
ocupacao_candidatos_pt_2014 = Counter(data_frame_pt_2014['DS_OCUPACAO'])
ocupacao_candidatos_pt_2014
# Out:
# Counter({'OUTROS': 1,
#          'GOVERNADOR': 1,
#          'DEPUTADO': 4,
#          'PROFESSOR DE ENSINO FUNDAMENTAL': 1,
#          'APOSENTADO (EXCETO SERVIDOR PÚBLICO)': 1,
#          'ECONOMISTA': 1,
#          'EMPRESÁRIO': 1,
#          'ADVOGADO': 1,
#          'ADMINISTRADOR': 1,
#          'SENADOR': 1})

# %%
data_frame_2018 = data_frame[data_frame['ANO_ELEICAO'] == 2018]

# %%
data_frame_2018
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 1      06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 2      06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 3      06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 4      06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 29175  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 29176  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 29177  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 29178  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 29179  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
#
# ...

# %%
data_frame_pt_2018 = data_frame_2018.query("SG_PARTIDO == 'PT' & DS_SIT_TOT_TURNO == 'ELEITO'")

# %%
data_frame_pt_2018
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 165    06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 1140   06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 609    06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 1520   06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 3138   06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 7899   06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 9769   06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 10828  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 12061  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 20277  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# 26756  06/03/2022   11:03:02         2018                2  ELEIÇÃO ORDINÁRIA
# ...

# %%
data_frame_pt_2018['SG_PARTIDO'].unique()
# Out:
# <StringArray>
# ['PT']
# Length: 1, dtype: string

# %%
data_frame_pt_2018['DS_OCUPACAO'].unique()
# Out:
# <StringArray>
# [                                    'INDUSTRIAL',
#                                      'ECONOMISTA',
#                                         'SENADOR',
#                    'PROFESSOR DE ENSINO SUPERIOR',
#                                       'SOCIÓLOGO',
#                                          'OUTROS',
#                                      'AGRICULTOR',
#                                      'GOVERNADOR',
#                                        'AGRÔNOMO',
#                       'PROFESSOR DE ENSINO MÉDIO',
#  'PROFESSOR E INSTRUTOR DE FORMAÇÃO PROFISSIONAL']
# Length: 11, dtype: string

# %%
ocupacao_candidatos_pt_2018 = Counter(data_frame_pt_2018['DS_OCUPACAO'])
ocupacao_candidatos_pt_2018
# Out:
# Counter({'INDUSTRIAL': 1,
#          'ECONOMISTA': 1,
#          'SENADOR': 3,
#          'PROFESSOR DE ENSINO SUPERIOR': 1,
#          'SOCIÓLOGO': 1,
#          'OUTROS': 2,
#          'AGRICULTOR': 1,
#          'GOVERNADOR': 1,
#          'AGRÔNOMO': 1,
#          'PROFESSOR DE ENSINO MÉDIO': 1,
#          'PROFESSOR E INSTRUTOR DE FORMAÇÃO PROFISSIONAL': 1})

# %%
ocupacao_candidatos_pt_2014
# Out:
# Counter({'OUTROS': 1,
#          'GOVERNADOR': 1,
#          'DEPUTADO': 4,
#          'PROFESSOR DE ENSINO FUNDAMENTAL': 1,
#          'APOSENTADO (EXCETO SERVIDOR PÚBLICO)': 1,
#          'ECONOMISTA': 1,
#          'EMPRESÁRIO': 1,
#          'ADVOGADO': 1,
#          'ADMINISTRADOR': 1,
#          'SENADOR': 1})

# %%
#Criação de listas contendo ocupação dos candidatos do PT eleitos em 2014
lista_candidatos_pt_2014_labels = []
lista_candidatos_pt_2014_valores = []
for x, y in ocupacao_candidatos_pt_2014.items():
    lista_candidatos_pt_2014_labels.append(x)
    lista_candidatos_pt_2014_valores.append(y)

# %%
#Plotagem do gráfico de escolaridade dos candidatos eleitos
plt.style.use('ggplot')
plt.barh(lista_candidatos_pt_2014_labels, 
         lista_candidatos_pt_2014_valores)
plt.ylabel('ocupação dos candidatos')
plt.xlabel('Número de candidatos - Ano base 2014')
plt.title('Candidatos eleitos por Ocupação - Partido dos Trabalhadores')
plt.show()

# %%
#Criação de listas contendo ocupação dos candidatos do PT eleitos em 2018
lista_candidatos_pt_2018_labels = []
lista_candidatos_pt_2018_valores = []
for x, y in ocupacao_candidatos_pt_2018.items():
    lista_candidatos_pt_2018_labels.append(x)
    lista_candidatos_pt_2018_valores.append(y)

# %%
#Plotagem do gráfico de escolaridade dos candidatos eleitos
plt.style.use('ggplot')
plt.barh(lista_candidatos_pt_2018_labels, 
         lista_candidatos_pt_2018_valores)
plt.ylabel('escolaridade')
plt.xlabel('Ocupação dos candidatos')
plt.title('Candidatos eleitos por ocupação')
plt.show()

# %% [markdown]
# <b>Análise conclusiva</b>
#
# Pode- se constatar, na análise em questão, uma cresente exponencial do Partido dos Trabalhadores em uma sequência de 2 eleições, o que se infere a maior ocupação dos candidatos eleitos no ano base 2014, candidatos na ocupação Deputados, sendo as demais ocupações em uma média fixa correlacional. O ano base 2018, infere-se analiticamente a ocupação senador a maior dentre as demais.
